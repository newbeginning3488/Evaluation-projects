# %% [markdown]
# # AVACADO DATASET

# %% [markdown]
# Problem Statement:- We have avacado dataset which has features like date,total volume,4046,4225,4770,total bags,large bags, xlarge bags,type,year region. By using this feaatures i will predict the average price in this project. As average price is a numerical value and continuous in nature so i will use regression method to predict the average price. The prediction includes many procedures like EDA,Data Preprocessing, Feauture engineering, Model selection by using different algorithm etc. I will use certain libraries to reach my goal and good accuracy score.
#
# We have two types of Avocado available here:
#
# 1.Organic which is healthy
#
# 2.Conventional
#
# The variables on this dataset available are as follows:
#
# 1.Categorical: ‘region’,’type’
#
# 2.Date: ‘Date’
#
# 3.Numerical:’Total Volume’, ‘4046’, ‘4225’, ‘4770’, ‘Total Bags’, ‘Small Bags’,’Large Bags’,’XLarge Bags’,’Year’
#
# Target:‘AveragePrice’

# %%
# import important libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset
df= pd.read_csv("Avacado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  27/12/2015          1.33      64236.62  1036.74   54454.85
# 1               1  20/12/2015          1.35      54876.98   674.28   44638.81
# 2               2  13/12/2015          0.93     118220.22   794.70  109149.67
# 3               3  06/12/2015          1.08      78992.15  1132.00   71976.41
# 4               4  29/11/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  04/02/2018          1.63      17074.83  2046.96    1529.20
# 18245           8  28/01/2018          1.71      13888.04  1191.70    3431.50
# 18246           9  21/01/2018          1.87      13766.76  1191.92    2452.79
# 18247          10  14/01/2018          1.93      16205.22  1527.63    2981.04
# 18248          11  07/01/2018          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29/11/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  04/02/2018          1.63      17074.83  2046.96  1529.20    0.00
# 18245  28/01/2018          1.71      13888.04  1191.70  3431.50    0.00
# 18246  21/01/2018          1.87      13766.76  1191.92  2452.79  727.94
# 18247  14/01/2018          1.93      16205.22  1527.63  2981.04  727.01
# 18248  07/01/2018          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.sample()
# Out:
#            Date  AveragePrice  Total Volume      4046       4225    4770  \
# 974  05/04/2015          0.83     1249645.2  608887.6  496479.07  4878.2
#
#      Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 974   139400.33   132586.15     6814.18          0.0  conventional  2015
#
#       region
# 974  Houston

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# From above observation we can see that there 3 columns datatypes is object and rest are float so we have to convert object into int or float for model building.
#
# As per above observation we have seen that the date is object type so we have to change it into date type so we caan use this in model building

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000
#
#               Month           Day
# count  18249.000000  18249.000000
# mean       6.372842     15.466984
# std        3.525034      8.984552
# min        1.000000      1.000000
# 25%        3.000000      7.000000
# 50%        6.000000     16.000000
# 75%       10.000000     23.000000
# max       12.000000     31.000000

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int32
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %% [markdown]
# # 1 Classifiation : Type Conventional / Organic

# %%
df.year.unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df.type
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type, Length: 18249, dtype: object

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
sns.boxplot(y="type", x="AveragePrice", data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %% [markdown]
# The above boxplot shows that the average prcie of organic avocado is more that the conventional avocado.

# %%
df.keys()
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Month', 'Day'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.head(2)
# Out:
#          Date  AveragePrice  Total Volume     4046      4225   4770  \
# 0  27/12/2015          1.33      64236.62  1036.74  54454.85  48.16
# 1  20/12/2015          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 13)

# %%
sns.pairplot(df)

# %% [markdown]
# Through the above and below graph we have come accros to the attributes or the fields which are positively corelated or neutral corelated to each other, Hence we would be taking them in to the consideration.
#
# These fields are : 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year'.
#
# These fields are some what showing positive or neutral correlation with each other.

# %%
sns.pairplot(df, x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], y_vars='Total Volume', size=4, aspect=1, kind='reg')

# %%
sns.pairplot(df, x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], y_vars='Total Bags', size=4, aspect=1, kind='reg')

# %%
sns.pairplot(df, x_vars=['4046', '4225', '4770'], y_vars='Total Volume', size=4, aspect=1, kind='reg')

# %%
sns.pairplot(df, x_vars=['4046', '4225', '4770'], y_vars='Total Bags', size=4, aspect=1, kind='reg')

# %% [markdown]
# Plotting the above graphs, in order to know that how the variables are corelating with "Total Volumes" and "Total Bags" field, where we see that :
#
# Strong Positive correlation:
#
# '4046', '4225', '4770'.
#
# 'Small Bags', 'Large Bags', 'XLarge Bags'.
#
# The below graph shows is the stucture of corelation between each of the variables with respect to the heatmap.The black dots represent negative corelation where as off white color shows the positive corelation.

# %%
corr_hmap=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
df.plot(kind='box',subplots=True, layout=(2,10))
# Out:
# AveragePrice       AxesSubplot(0.125,0.536818;0.065678x0.343182)
# Total Volume    AxesSubplot(0.203814,0.536818;0.065678x0.343182)
# 4046            AxesSubplot(0.282627,0.536818;0.065678x0.343182)
# 4225            AxesSubplot(0.361441,0.536818;0.065678x0.343182)
# 4770            AxesSubplot(0.440254,0.536818;0.065678x0.343182)
# Total Bags      AxesSubplot(0.519068,0.536818;0.065678x0.343182)
# Small Bags      AxesSubplot(0.597881,0.536818;0.065678x0.343182)
# Large Bags      AxesSubplot(0.676695,0.536818;0.065678x0.343182)
# XLarge Bags     AxesSubplot(0.755508,0.536818;0.065678x0.343182)
# year            AxesSubplot(0.834322,0.536818;0.065678x0.343182)
# Month                 AxesSubplot(0.125,0.125;0.065678x0.343182)
# Day                AxesSubplot(0.203814,0.125;0.065678x0.343182)
# dtype: object

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df.iloc[:,2],df.iloc[:,3])
plt.show()

# %%
plt.scatter(df.iloc[:,3],df.iloc[:,4])
plt.show()

# %%
plt.scatter(df.iloc[:,1],df.iloc[:,4])
plt.show()

# %%
#Average price mostly lies between $1 to $1.5
df['AveragePrice'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Total Volumes
df['Total Volume'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Total Bags
df['Total Bags'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Small Bags
df['Small Bags'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # REGION AND AVERAGE PRICE DISTRIBUTION

# %%
plt.figure(figsize=(12,20))
sns.set_style('whitegrid')
sns.pointplot(x='AveragePrice', y='region', data=df, hue='type',join=False)
plt.xlabel('Average Price',{'fontsize' : 'large'})
plt.ylabel('Region or Cities',{'fontsize':'large'})
plt.title("Average Price in Each Region",{'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Average Price in Each Region')

# %%
plt.figure(figsize=(12,20))
sns.set_style('whitegrid')
sns.pointplot(x='AveragePrice', y='region', data=df, hue='year',join=False)
plt.xlabel('Average Price',{'fontsize' : 'large'})
plt.ylabel('Region or Cities',{'fontsize':'large'})
plt.title("Average Price in Each Region",{'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Average Price in Each Region')

# %%
#Checking distribution of all columns by plotting histogram
df.hist(edgecolor="red",linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>],
#        [<AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # ASSIGNING X AND Y VARIABLE

# %%
df.head(5)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29/11/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
x=df.iloc[:,1:-3]
x
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags
# 0         8603.62       93.25          0.0
# 1         9408.07       97.49          0.0
# 2         8042.21      103.14          0.0
# 3         5677.40      133.76          0.0
# 4         5986.26      197.69          0.0
# ...           ...         ...          ...
# 18244    13066.82      431.85          0.0
# 18245     8940.04      324.80          0.0
# 18246     9351.80       42.31          0.0
# 18247    10919.54       50.00          0.0
# 18248    11988.14       26.01          0.0
#
# [18249 rows x 9 columns]

# %%
x.shape
# Out:
# (18249, 9)

# %%
y=df.iloc[:,-3]
y
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type, Length: 18249, dtype: object

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# # MODEL SELECTION

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.20,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score correspondint to: ",final_r_state,"is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.3859167203656523
# r2_score corresponding to random state:  43 is:  0.40776171628779445
# r2_score corresponding to random state:  44 is:  0.38472418317513146
# r2_score corresponding to random state:  45 is:  0.3887540871953775
# r2_score corresponding to random state:  46 is:  0.38659777217152913
# r2_score corresponding to random state:  47 is:  0.4028957450047298
# r2_score corresponding to random state:  48 is:  0.4133452347258799
# r2_score corresponding to random state:  49 is:  0.4090307197725692
# r2_score corresponding to random state:  50 is:  0.41727995593378175
# r2_score corresponding to random state:  51 is:  0.4073113515213934
# r2_score corresponding to random state:  52 is:  0.3984755656662913
# r2_score corresponding to random state:  53 is:  0.39920569173698217
# r2_score corresponding to random state:  54 is:  0.38139596528305586
# r2_score corresponding to random state:  55 is:  0.40459518901986125
# r2_score corresponding to random state:  56 is:  0.41173886965121775
# r2_score corresponding to random state:  57 is:  0.3942177934941443
# r2_score corresponding to random state:  58 is:  0.39780625495707067
# r2_score corresponding to random state:  59 is:  0.4010202201867782
# r2_score corresponding to random state:  60 is:  0.40276791291460534
# r2_score corresponding to random state:  61 is:  0.3841445627258341
# r2_score corresponding to random state:  62 is:  0.4053660401988298
# r2_score corresponding to random state:  63 is:  0.3942079384598963
# r2_score corresponding to random state:  64 is:  0.4023413935092949
# r2_score corresponding to random state:  65 is:  0.3999559039630922
# r2_score corresponding to random state:  66 is:  0.4173144605705046
# r2_score corresponding to random state:  67 is:  0.3982616515602828
# r2_score corresponding to random state:  68 is:  0.39976814023825413
# r2_score corresponding to random state:  69 is:  0.4061376700550491
# r2_score corresponding to random state:  70 is:  0.40455424625322467
# r2_score corresponding to random state:  71 is:  0.40553145211343367
# r2_score corresponding to random state:  72 is:  0.3821649176199322
# r2_score corresponding to random state:  73 is:  0.4001042067580557
# r2_score corresponding to random state:  74 is:  0.40320445024588747
# r2_score corresponding to random state:  75 is:  0.37823584924217357
# r2_score corresponding to random state:  76 is:  0.4118265735052672
# r2_score corresponding to random state:  77 is:  0.41480008961639736
# r2_score corresponding to random state:  78 is:  0.4067077252629244
# r2_score corresponding to random state:  79 is:  0.40732307866216844
# r2_score corresponding to random state:  80 is:  0.3881304921955072
# r2_score corresponding to random state:  81 is:  0.3854553020026985
# r2_score corresponding to random state:  82 is:  0.40485822999505894
# r2_score corresponding to random state:  83 is:  0.3998736158571343
# r2_score corresponding to random state:  84 is:  0.3977898432643744
# r2_score corresponding to random state:  85 is:  0.4105108763593607
# r2_score corresponding to random state:  86 is:  0.4078565928269312
# r2_score corresponding to random state:  87 is:  0.4004203096145086
# r2_score corresponding to random state:  88 is:  0.41705060599541544
# r2_score corresponding to random state:  89 is:  0.40809027516964236
# r2_score corresponding to random state:  90 is:  0.38203081789224513
# r2_score corresponding to random state:  91 is:  0.3894449249548143
# r2_score corresponding to random state:  92 is:  0.40627507616737546
# r2_score corresponding to random state:  93 is:  0.3904360123241726
# r2_score corresponding to random state:  94 is:  0.42367131548149384
# r2_score corresponding to random state:  95 is:  0.39032353714387236
# r2_score corresponding to random state:  96 is:  0.40893036524926174
# r2_score corresponding to random state:  97 is:  0.37427840645915045
# r2_score corresponding to random state:  98 is:  0.4016079819401349
# r2_score corresponding to random state:  99 is:  0.3929992924343554
#
#
# max r2_score correspondint to:  94 is  0.42367131548149384

# %% [markdown]
# # Logistic Regression
# Gaussian NB
# SVC
# Decision Tree Classifier
# KNeighbors Classifier

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state= 9,stratify=y)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (12774, 9) (5475, 9)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (12774,) (5475,)

# %%
LOR=LogisticRegression()
GNB=GaussianNB()
SVC=SVC()
DTC=DecisionTreeClassifier(random_state=10)
KNN=KNeighborsClassifier()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
models= []
models.append(('LogisticRegression',LOR))
models.append(('GaussianNB',GNB))
models.append(('SVC',SVC))
models.append(('DecisionTreeClassifier',DTC))
models.append(('KNeighborsClassifie',KNN))

# %%
Model = []
score = []
cvs = []
rocscore = []
for name,model in models:
    print('****************',name,'****************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    AS= accuracy_score(y_test,pred)
    print('ACCURACY SCORE IS = ',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('CROSS_VAL_SCORE = ',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('ROC_AUC_SCORE = ',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('CLASSIFICATION REPORT = ',classification_report(y_test,pred))
    print('\n')
    cm=confusion_matrix(y_test,pred)
    print('CONFUSION MATRIX',cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'k--')
    plt.plot(false_positive_rate,true_positive_rate,label='AUC= %.2f'% roc_auc)
    plt.xlabel('false positive rate')
    plt.ylabel('true positive rate')
    plt.title(name)
    plt.show()
    print('\n\n')
# Out:
# **************** LogisticRegression ****************
#
#
# LogisticRegression()
#
#
# ACCURACY SCORE IS =  0.93662100456621
#
#
# CROSS_VAL_SCORE =  0.887777667627974
#
#
# ROC_AUC_SCORE =  0.9366273075749816
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93      2738
#            1       0.91      0.97      0.94      2737
#
#     accuracy                           0.94      5475
#    macro avg       0.94      0.94      0.94      5475
# weighted avg       0.94      0.94      0.94      5475
#
#
#
# CONFUSION MATRIX [[2470  268]
#  [  79 2658]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# **************** GaussianNB ****************
#
#
# GaussianNB()
#
#
# ACCURACY SCORE IS =  0.845662100456621
#
#
# CROSS_VAL_SCORE =  0.8473350757029561
#
#
# ROC_AUC_SCORE =  0.8456856144179017
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.97      0.72      0.82      2738
#            1       0.77      0.97      0.86      2737
#
#     accuracy                           0.85      5475
#    macro avg       0.87      0.85      0.84      5475
# weighted avg       0.87      0.85      0.84      5475
#
#
#
# CONFUSION MATRIX [[1963  775]
#  [  70 2667]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# **************** SVC ****************
#
#
# SVC()
#
#
# ACCURACY SCORE IS =  0.891324200913242
#
#
# CROSS_VAL_SCORE =  0.8946761595770247
#
#
# ROC_AUC_SCORE =  0.8913326374790396
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      2738
#            1       0.86      0.94      0.90      2737
#
#     accuracy                           0.89      5475
#    macro avg       0.89      0.89      0.89      5475
# weighted avg       0.89      0.89      0.89      5475
#
#
#
# CONFUSION MATRIX [[2314  424]
#  [ 171 2566]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# **************** DecisionTreeClassifier ****************
#
#
# DecisionTreeClassifier(random_state=10)
#
#
# ACCURACY SCORE IS =  0.982283105022831
#
#
# CROSS_VAL_SCORE =  0.9622428502763759
#
#
# ROC_AUC_SCORE =  0.9822828041878294
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2738
#            1       0.98      0.98      0.98      2737
#
#     accuracy                           0.98      5475
#    macro avg       0.98      0.98      0.98      5475
# weighted avg       0.98      0.98      0.98      5475
#
#
#
# CONFUSION MATRIX [[2694   44]
#  [  53 2684]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# **************** KNeighborsClassifie ****************
#
#
# KNeighborsClassifier()
#
#
# ACCURACY SCORE IS =  0.970593607305936
#
#
# CROSS_VAL_SCORE =  0.9388454397981254
#
#
# ROC_AUC_SCORE =  0.970592572151292
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      2738
#            1       0.98      0.96      0.97      2737
#
#     accuracy                           0.97      5475
#    macro avg       0.97      0.97      0.97      5475
# weighted avg       0.97      0.97      0.97      5475
#
#
#
# CONFUSION MATRIX [[2673   65]
#  [  96 2641]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %%
result=pd.DataFrame({'Model': Model,'Accuracy_score': score,'Cross_val_score': cvs,'Roc_auc_curve': rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  Roc_auc_curve
# 0      LogisticRegression       93.662100        88.777767      93.662731
# 1              GaussianNB       84.566210        84.733508      84.568561
# 2                     SVC       89.132420        89.467616      89.133264
# 3  DecisionTreeClassifier       98.228311        96.224285      98.228280
# 4     KNeighborsClassifie       97.059361        93.884544      97.059257

# %% [markdown]
# # RANDOM FOREST REGRESSOR AND GRIDSEARCHCV

# %%
from math import log
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
estimator = RandomForestRegressor()
param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

grid.fit(x_train, y_train)

grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 20}

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=42,stratify=y)
rfr2=RandomForestRegressor(bootstrap=False,max_features='sqrt',min_samples_split=2,n_estimators=30)
rfr2.fit(x_train, y_train)
rfr2.score(x_train,y_train)
pred1=rfr2.predict(x_test)
rfr2.score(x_train,y_train)
# Out:
# 1.0

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# # RANDOM FOREST REGRESSOR IS BEST MODEL SO FAR

# %% [markdown]
# # SAVING THE MODEL

# %%
import pickle
filename='Avacado_.pkl'
pickle.dump(rfr2, open(filename,'wb'))

# %%
#Pridicting x_test Classification = rfr2
rfr2.predict(x_test)
# Out:
# array([0., 0., 1., ..., 0., 0., 1.])

# %% [markdown]
# # 2.PREDICTING THE AVERAGE PRICE OF AVACADO

# %%
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29/11/2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  04/02/2018          1.63      17074.83  2046.96    1529.20    0.00
# 18245  28/01/2018          1.71      13888.04  1191.70    3431.50    0.00
# 18246  21/01/2018          1.87      13766.76  1191.92    2452.79  727.94
# 18247  14/01/2018          1.93      16205.22  1527.63    2981.04  727.01
# 18248  07/01/2018          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
df1=pd.DataFrame(data=df)
df1
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29/11/2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  04/02/2018          1.63      17074.83  2046.96    1529.20    0.00
# 18245  28/01/2018          1.71      13888.04  1191.70    3431.50    0.00
# 18246  21/01/2018          1.87      13766.76  1191.92    2452.79  727.94
# 18247  14/01/2018          1.93      16205.22  1527.63    2981.04  727.01
# 18248  07/01/2018          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27/12/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20/12/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13/12/2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06/12/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29/11/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#Droppig of the columns:
df1.drop(['Date', 'Total Volume', 'Total Bags', 'region', 'year',], axis = 1,inplace = True)

# %%
df1.tail()
# Out:
#        AveragePrice     4046     4225    4770  Small Bags  Large Bags  \
# 18244          1.63  2046.96  1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70  3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92  2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63  2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77  2356.13  224.53    11988.14       26.01
#
#        XLarge Bags     type
# 18244          0.0  organic
# 18245          0.0  organic
# 18246          0.0  organic
# 18247          0.0  organic
# 18248          0.0  organic

# %%
#Replacing the values of the type in to 0 and 1 :
df1["type"].replace({"conventional":0,"organic":1},inplace=True)
print(df1)
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags  type
# 0              0.0     0
# 1              0.0     0
# 2              0.0     0
# 3              0.0     0
# 4              0.0     0
# ...            ...   ...
# 18244          0.0     1
# 18245          0.0     1
# 18246          0.0     1
# 18247          0.0     1
# 18248          0.0     1
#
# [18249 rows x 8 columns]

# %%
df1.head(2)
# Out:
#    AveragePrice     4046      4225   4770  Small Bags  Large Bags  \
# 0          1.33  1036.74  54454.85  48.16     8603.62       93.25
# 1          1.35   674.28  44638.81  58.33     9408.07       97.49
#
#    XLarge Bags  type
# 0          0.0     0
# 1          0.0     0

# %%
df1.dtypes
# Out:
# AveragePrice    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# AveragePrice    0
# 4046            0
# 4225            0
# 4770            0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CHECKING SKEWNESS

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
#Treatment for the skewed data:
for col in df1.columns:
    if df1.skew().loc[col]>0.55:
        df1[col]=np.log1p(df1[col])

# %%
df1.skew()
# Out:
# AveragePrice    0.138629
# 4046           -0.328195
# 4225           -0.486654
# 4770            0.099986
# Small Bags     -0.622148
# Large Bags     -0.547765
# XLarge Bags     1.176494
# type            0.000329
# dtype: float64

# %% [markdown]
# # STANDARD SCALER

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler(copy=True, with_mean=True, with_std=True).fit(df1)
df1_avo_scaler = scaler.transform(df1)
df1_avo = pd.DataFrame(df1_avo_scaler)
df1_avo.columns = ['AveragePrice', '4046', '4225', '4770', 'Small Bags', 'Large Bags', 'XLarge Bags', 'Type']
df1_avo.head(10)
# Out:
#    AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0     -0.111918 -0.609752  0.374936 -0.279143   -0.247796   -0.669747
# 1     -0.060020 -0.737707  0.305200 -0.233838   -0.213093   -0.658279
# 2     -1.255560 -0.688840  0.618892 -0.042078   -0.273995   -0.643743
# 3     -0.801087 -0.583598  0.472808 -0.181974   -0.409182   -0.576571
# 4     -0.243636 -0.638425  0.298852 -0.171717   -0.388616   -0.475393
# 5     -0.297133 -0.570167  0.331167 -0.302543   -0.353293   -0.589089
# 6     -1.069669 -0.527051  0.480981 -0.122298   -0.266602   -0.600261
# 7     -1.100259 -0.724986  0.594488 -0.158826   -0.370832   -0.203799
# 8     -0.978816 -0.613968  0.540587 -0.143444   -0.148726   -0.381540
# 9     -0.830350 -0.671503  0.435728 -0.076486   -0.273066   -0.202839
#
#    XLarge Bags      Type
# 0    -0.645526 -0.999836
# 1    -0.645526 -0.999836
# 2    -0.645526 -0.999836
# 3    -0.645526 -0.999836
# 4    -0.645526 -0.999836
# 5    -0.645526 -0.999836
# 6    -0.645526 -0.999836
# 7    -0.645526 -0.999836
# 8    -0.645526 -0.999836
# 9    -0.645526 -0.999836

# %%
df1_avo.plot(kind='box',subplots=True, layout=(2,5))
# Out:
# AveragePrice       AxesSubplot(0.125,0.536818;0.133621x0.343182)
# 4046            AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# 4225             AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# 4770            AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Small Bags      AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Large Bags            AxesSubplot(0.125,0.125;0.133621x0.343182)
# XLarge Bags        AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Type                AxesSubplot(0.44569,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z_score=abs(zscore(df1_avo))
print(df1_avo.shape)
# Out:
# (18249, 8)

# %%
df2=df1_avo.loc[(z_score<3).all(axis=1)]
print(df2.shape)
# Out:
# (17953, 8)

# %%
#data loss
(18249-17593)/18249*100
# Out:
# 3.5947175187681513

# %% [markdown]
# # ASSIGNING X AND Y VARIABLES

# %%
df2.head(2)
# Out:
#    AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0     -0.111918 -0.609752  0.374936 -0.279143   -0.247796   -0.669747
# 1     -0.060020 -0.737707  0.305200 -0.233838   -0.213093   -0.658279
#
#    XLarge Bags      Type
# 0    -0.645526 -0.999836
# 1    -0.645526 -0.999836

# %%
x=df2.iloc[:,1:8]
x.shape
x
# Out:
#            4046      4225      4770  Small Bags  Large Bags  XLarge Bags  \
# 0     -0.609752  0.374936 -0.279143   -0.247796   -0.669747    -0.645526
# 1     -0.737707  0.305200 -0.233838   -0.213093   -0.658279    -0.645526
# 2     -0.688840  0.618892 -0.042078   -0.273995   -0.643743    -0.645526
# 3     -0.583598  0.472808 -0.181974   -0.409182   -0.576571    -0.645526
# 4     -0.638425  0.298852 -0.171717   -0.388616   -0.475393    -0.645526
# ...         ...       ...       ...         ...         ...          ...
# 18244 -0.407310 -0.878279 -1.217613   -0.085548   -0.272479    -0.645526
# 18245 -0.568306 -0.594835 -1.217613   -0.232904   -0.346517    -0.645526
# 18246 -0.568251 -0.712597  0.370548   -0.215422   -0.872380    -0.645526
# 18247 -0.494407 -0.644192  0.370240   -0.155249   -0.829787    -0.645526
# 18248 -0.304151 -0.726698  0.087895   -0.119000   -0.995429    -0.645526
#
#            Type
# 0     -0.999836
# 1     -0.999836
# 2     -0.999836
# 3     -0.999836
# 4     -0.999836
# ...         ...
# 18244  1.000164
# 18245  1.000164
# 18246  1.000164
# 18247  1.000164
# 18248  1.000164
#
# [17953 rows x 7 columns]

# %%
y=df2.iloc[:,0:1]
y.shape
y
# Out:
#        AveragePrice
# 0         -0.111918
# 1         -0.060020
# 2         -1.255560
# 3         -0.801087
# 4         -0.243636
# ...             ...
# 18244      0.623491
# 18245      0.805435
# 18246      1.153743
# 18247      1.279375
# 18248      0.600359
#
# [17953 rows x 1 columns]

# %% [markdown]
# # LINEAR REGRESSION

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score correspondint to: ",final_r_state,"is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.45559341214210114
# r2_score corresponding to random state:  43 is:  0.4486603725494218
# r2_score corresponding to random state:  44 is:  0.45010279046140256
# r2_score corresponding to random state:  45 is:  0.4462330331292531
# r2_score corresponding to random state:  46 is:  0.44974084146422055
# r2_score corresponding to random state:  47 is:  0.45321945548787923
# r2_score corresponding to random state:  48 is:  0.45436866459963887
# r2_score corresponding to random state:  49 is:  0.4526760695186782
# r2_score corresponding to random state:  50 is:  0.45286776755388336
# r2_score corresponding to random state:  51 is:  0.4626144720332126
# r2_score corresponding to random state:  52 is:  0.45035789368915113
# r2_score corresponding to random state:  53 is:  0.47003670059803226
# r2_score corresponding to random state:  54 is:  0.44433726553228003
# r2_score corresponding to random state:  55 is:  0.46192527270684136
# r2_score corresponding to random state:  56 is:  0.4503321709012741
# r2_score corresponding to random state:  57 is:  0.43597254954864595
# r2_score corresponding to random state:  58 is:  0.4559371400622061
# r2_score corresponding to random state:  59 is:  0.4485304965097433
# r2_score corresponding to random state:  60 is:  0.4692516945485167
# r2_score corresponding to random state:  61 is:  0.4591556441787018
# r2_score corresponding to random state:  62 is:  0.4621975045970341
# r2_score corresponding to random state:  63 is:  0.4678515585254591
# r2_score corresponding to random state:  64 is:  0.4525631616095891
# r2_score corresponding to random state:  65 is:  0.46968943606530733
# r2_score corresponding to random state:  66 is:  0.4656410035277724
# r2_score corresponding to random state:  67 is:  0.47473557812447986
# r2_score corresponding to random state:  68 is:  0.45379032712200384
# r2_score corresponding to random state:  69 is:  0.46128090162288227
# r2_score corresponding to random state:  70 is:  0.44917007510195883
# r2_score corresponding to random state:  71 is:  0.46072421005199393
# r2_score corresponding to random state:  72 is:  0.4526312318834509
# r2_score corresponding to random state:  73 is:  0.44765957614427865
# r2_score corresponding to random state:  74 is:  0.4459571306270781
# r2_score corresponding to random state:  75 is:  0.449798856478579
# r2_score corresponding to random state:  76 is:  0.4603452085993759
# r2_score corresponding to random state:  77 is:  0.44564816488534575
# r2_score corresponding to random state:  78 is:  0.4570561469457548
# r2_score corresponding to random state:  79 is:  0.47834471917140264
# r2_score corresponding to random state:  80 is:  0.4633923771528756
# r2_score corresponding to random state:  81 is:  0.46685987383600525
# r2_score corresponding to random state:  82 is:  0.44948319629364786
# r2_score corresponding to random state:  83 is:  0.4542010005444552
# r2_score corresponding to random state:  84 is:  0.4519034375951583
# r2_score corresponding to random state:  85 is:  0.45535965245852883
# r2_score corresponding to random state:  86 is:  0.4707330259400119
# r2_score corresponding to random state:  87 is:  0.45960586191193165
# r2_score corresponding to random state:  88 is:  0.46092919720864856
# r2_score corresponding to random state:  89 is:  0.4537391090297286
# r2_score corresponding to random state:  90 is:  0.4595538344236162
# r2_score corresponding to random state:  91 is:  0.46897372666173276
# r2_score corresponding to random state:  92 is:  0.459130060504951
# r2_score corresponding to random state:  93 is:  0.4535540114137684
# r2_score corresponding to random state:  94 is:  0.4545166235786474
# r2_score corresponding to random state:  95 is:  0.44789347197367657
# r2_score corresponding to random state:  96 is:  0.4549047616704004
# r2_score corresponding to random state:  97 is:  0.4570995598138342
# r2_score corresponding to random state:  98 is:  0.4459594973614135
# r2_score corresponding to random state:  99 is:  0.457715595733978
#
#
# max r2_score correspondint to:  79 is  0.47834471917140264

# %% [markdown]
# # CROSS VALIDATION

# %%
cross_val_score(lr,x,y,cv=5,scoring='r2').mean()
# Out:
# 0.003593926227756272

# %%
cross_val_score(lr,x,y,cv=5,scoring='r2').std()
# Out:
# 0.2971497645617556

# %%
#predicting the Average Pricing of the Avocado:
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=79)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 0.1352094 ],
#        [-0.76036311],
#        [ 0.63543627],
#        ...,
#        [-0.15412619],
#        [ 0.59706872],
#        [-0.36951701]])

# %% [markdown]
# LASSO

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
isreh=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
grid=GridSearchCV(isreh,parameters,cv=10)
grid.fit(x,y)
grid.best_params_
# Out:
# {'alpha': 0.01}

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=r_state)
    lasso=Lasso(alpha=0.01)
    lasso.fit(x_train,y_train)
    y_pred=lasso.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score correspondint to: ",final_r_state,"is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.45369390875332705
# r2_score corresponding to random state:  43 is:  0.4465418172385406
# r2_score corresponding to random state:  44 is:  0.4487203982652763
# r2_score corresponding to random state:  45 is:  0.442238091766454
# r2_score corresponding to random state:  46 is:  0.4487194441493537
# r2_score corresponding to random state:  47 is:  0.4512615159072898
# r2_score corresponding to random state:  48 is:  0.45121489456294606
# r2_score corresponding to random state:  49 is:  0.45247543018927283
# r2_score corresponding to random state:  50 is:  0.44897428330340994
# r2_score corresponding to random state:  51 is:  0.4611770525993637
# r2_score corresponding to random state:  52 is:  0.4496263485419457
# r2_score corresponding to random state:  53 is:  0.46687610750584263
# r2_score corresponding to random state:  54 is:  0.4446216254201203
# r2_score corresponding to random state:  55 is:  0.46059259606736713
# r2_score corresponding to random state:  56 is:  0.4493108817186925
# r2_score corresponding to random state:  57 is:  0.4359410877527772
# r2_score corresponding to random state:  58 is:  0.4540591432669423
# r2_score corresponding to random state:  59 is:  0.447397861392417
# r2_score corresponding to random state:  60 is:  0.46593546434671107
# r2_score corresponding to random state:  61 is:  0.4571094000117474
# r2_score corresponding to random state:  62 is:  0.46030882155926034
# r2_score corresponding to random state:  63 is:  0.4636252544468936
# r2_score corresponding to random state:  64 is:  0.45036528388457064
# r2_score corresponding to random state:  65 is:  0.4675415852538176
# r2_score corresponding to random state:  66 is:  0.463653836032187
# r2_score corresponding to random state:  67 is:  0.4715739356297405
# r2_score corresponding to random state:  68 is:  0.45175412548172944
# r2_score corresponding to random state:  69 is:  0.4596598127166782
# r2_score corresponding to random state:  70 is:  0.448441688393036
# r2_score corresponding to random state:  71 is:  0.45833851746655896
# r2_score corresponding to random state:  72 is:  0.4500948316986013
# r2_score corresponding to random state:  73 is:  0.44625942743821023
# r2_score corresponding to random state:  74 is:  0.442323442097281
# r2_score corresponding to random state:  75 is:  0.4484242056145805
# r2_score corresponding to random state:  76 is:  0.4573208570332038
# r2_score corresponding to random state:  77 is:  0.44328712597659414
# r2_score corresponding to random state:  78 is:  0.4536478154418975
# r2_score corresponding to random state:  79 is:  0.4772753793610759
# r2_score corresponding to random state:  80 is:  0.46061473138043096
# r2_score corresponding to random state:  81 is:  0.464193731589458
# r2_score corresponding to random state:  82 is:  0.4503666631996629
# r2_score corresponding to random state:  83 is:  0.45206865424131026
# r2_score corresponding to random state:  84 is:  0.44988221969085285
# r2_score corresponding to random state:  85 is:  0.4549225763675052
# r2_score corresponding to random state:  86 is:  0.46783636362492265
# r2_score corresponding to random state:  87 is:  0.45613639958581587
# r2_score corresponding to random state:  88 is:  0.4571247587289079
# r2_score corresponding to random state:  89 is:  0.452580176878558
# r2_score corresponding to random state:  90 is:  0.45724652551362344
# r2_score corresponding to random state:  91 is:  0.4680298562202836
# r2_score corresponding to random state:  92 is:  0.4579240130218132
# r2_score corresponding to random state:  93 is:  0.452193284981952
# r2_score corresponding to random state:  94 is:  0.45360051612322494
# r2_score corresponding to random state:  95 is:  0.44659002540444914
# r2_score corresponding to random state:  96 is:  0.4542141816923291
# r2_score corresponding to random state:  97 is:  0.45511979900760335
# r2_score corresponding to random state:  98 is:  0.44322607739506115
# r2_score corresponding to random state:  99 is:  0.4553561324411254
#
#
# max r2_score correspondint to:  79 is  0.4772753793610759

# %% [raw]
# ERRORS

# %%
print("r2 score is : ",r2_score(y_test,y_pred))
print('Mean absolute error : ',mean_absolute_error(y_test,y_pred))
print('Mean Squared error : ',mean_squared_error(y_test,y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is :  0.4553561324411254
# Mean absolute error :  0.5731855960986175
# Mean Squared error :  0.5460440315147906
# RMSE is :  0.7389479220586459

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
from math import log
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
#to find out the best parameters in the random forest regressor:
estimator = RandomForestRegressor()
param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

grid.fit(x_train, y_train)

grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'log2',
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
rf1=RandomForestRegressor(bootstrap=False,max_features='log2',min_samples_split=2,n_estimators=30)
rf1.fit(x_train, y_train)
rf1.score(x_train,y_train)
pred=rf1.predict(x_test)

# %%
pred
# Out:
# array([-0.09498437, -0.41486244, -0.56748045, ..., -1.5346839 ,
#        -1.40808171, -0.26437325])

# %%
rf1.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# # saving the model

# %%
import pickle
filename='avacado_.pkl'
pickle.dump(rf1, open(filename,'wb'))

# %%
#Pridicting x_test Regression = rf1
rf1.predict(x_test)
# Out:
# array([-0.09498437, -0.41486244, -0.56748045, ..., -1.5346839 ,
#        -1.40808171, -0.26437325])

# %% [markdown]
# # --------END----
